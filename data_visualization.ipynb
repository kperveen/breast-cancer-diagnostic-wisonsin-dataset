# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data = data.drop(['Unnamed: 32'], axis = 1)

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data['diagnosis']=data['diagnosis'].map({'B':0,'M':1})

# %%
data.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
import matplotlib.pyplot as plot

# %%
data['diagnosis'].value_counts().plot(kind = 'bar')

# %%
ax = plot.gca()
data['diagnosis'].value_counts().plot(kind = 'bar')
ax.set_xticklabels(['Benign','Malignant'])
# Out:
# [Text(0, 0, 'Benign'), Text(0, 0, 'Malignant')]

# %%
data_correlation = data.corr()

# %%
data_correlation.head()
# Out:
#                       id  diagnosis  radius_mean  texture_mean  \
# id              1.000000   0.039769     0.074626      0.099770
# diagnosis       0.039769   1.000000     0.730029      0.415185
# radius_mean     0.074626   0.730029     1.000000      0.323782
# texture_mean    0.099770   0.415185     0.323782      1.000000
# perimeter_mean  0.073159   0.742636     0.997855      0.329533
#
#                 perimeter_mean  area_mean  smoothness_mean  compactness_mean  \
# id                    0.073159   0.096893        -0.012968          0.000096
# diagnosis             0.742636   0.708984         0.358560          0.596534
# radius_mean           0.997855   0.987357         0.170581          0.506124
# texture_mean          0.329533   0.321086        -0.023389          0.236702
# perimeter_mean        1.000000   0.986507         0.207278          0.556936
#
#                 concavity_mean  concave points_mean  ...  radius_worst  \
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(data_correlation)
fig = plot.gcf()
fig.set_size_inches(8, 8)

# %%
data_correlation['diagnosis'].sort_values().plot(kind='bar',sort_columns=True)
fig = plot.gcf()
fig.set_size_inches(8, 8)

# %%
print(data_correlation['diagnosis'].sort_values(ascending=False))
# Out:
# diagnosis                  1.000000
# concave points_worst       0.793566
# perimeter_worst            0.782914
# concave points_mean        0.776614
# radius_worst               0.776454
# perimeter_mean             0.742636
# area_worst                 0.733825
# radius_mean                0.730029
# area_mean                  0.708984
# concavity_mean             0.696360
# concavity_worst            0.659610
# compactness_mean           0.596534
# compactness_worst          0.590998
# radius_se                  0.567134
# perimeter_se               0.556141
# area_se                    0.548236
# texture_worst              0.456903
# smoothness_worst           0.421465
# symmetry_worst             0.416294
# texture_mean               0.415185
# concave points_se          0.408042
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# fractal_dimension_worst    0.323872
# compactness_se             0.292999
# concavity_se               0.253730
# ...

# %%
sns.kdeplot(data.loc[(data['diagnosis']==0),'radius_mean'], color='r', shade=True, label = "Bening") 
  
sns.kdeplot(data.loc[(data['diagnosis']==1),'radius_mean'], color='b', shade=True, label = "Malignant")
plot.title("Radius_mean")
# Out:
# Text(0.5, 1.0, 'Radius_mean')

# %%
sns.kdeplot(data.loc[(data['diagnosis']==0),'texture_mean'], color='r', shade=True, label = "Bening") 
  
sns.kdeplot(data.loc[(data['diagnosis']==1),'texture_mean'], color='b', shade=True, label = "Malignant")
plot.title("texture_mean")
# Out:
# Text(0.5, 1.0, 'texture_mean')

# %%
sns.kdeplot(data.loc[(data['diagnosis']==0),'perimeter_mean'], color='r', shade=True, label = "Bening") 
  
sns.kdeplot(data.loc[(data['diagnosis']==1),'perimeter_mean'], color='b', shade=True, label = "Malignant")
plot.title("perimeter_mean")
# Out:
# Text(0.5, 1.0, 'perimeter_mean')

# %%
sns.kdeplot(data.loc[(data['diagnosis']==0),'area_mean'], color='r', shade=True, label = "Bening") 
  
sns.kdeplot(data.loc[(data['diagnosis']==1),'area_mean'], color='b', shade=True, label = "Malignant")
plot.title("area_mean")
# Out:
# Text(0.5, 1.0, 'area_mean')

# %%
sns.kdeplot(data.loc[(data['diagnosis']==0),'smoothness_mean'], color='r', shade=True, label = "Bening") 
  
sns.kdeplot(data.loc[(data['diagnosis']==1),'smoothness_mean'], color='b', shade=True, label = "Malignant")
plot.title("smoothness_mean")
# Out:
# Text(0.5, 1.0, 'smoothness_mean')

# %%
sns.kdeplot(data.loc[(data['diagnosis']==0),'compactness_mean'], color='r', shade=True, label = "Bening") 
  
sns.kdeplot(data.loc[(data['diagnosis']==1),'compactness_mean'], color='b', shade=True, label = "Malignant")
plot.title("compactness_mean")
# Out:
# Text(0.5, 1.0, 'compactness_mean')

# %%
sns.kdeplot(data.loc[(data['diagnosis']==0),'concavity_mean'], color='r', shade=True, label = "Bening") 
  
sns.kdeplot(data.loc[(data['diagnosis']==1),'concavity_mean'], color='b', shade=True, label = "Malignant")
plot.title("concavity_mean")
# Out:
# Text(0.5, 1.0, 'concavity_mean')

# %%
sns.kdeplot(data.loc[(data['diagnosis']==0),'concave points_mean'], color='r', shade=True, label = "Bening") 
  
sns.kdeplot(data.loc[(data['diagnosis']==1),'concave points_mean'], color='b', shade=True, label = "Malignant")
plot.title("concave points_mean")
# Out:
# Text(0.5, 1.0, 'concave points_mean')

# %%
sns.kdeplot(data.loc[(data['diagnosis']==0),'fractal_dimension_mean'], color='r', shade=True, label = "Bening") 
  
sns.kdeplot(data.loc[(data['diagnosis']==1),'fractal_dimension_mean'], color='b', shade=True, label = "Malignant")
plot.title("fractal_dimension_mean")
# Out:
# Text(0.5, 1.0, 'fractal_dimension_mean')

# %%
data['diagnosis']=data['diagnosis'].map({0:'Bening',1:'Malignant'})

# %%
data.boxplot(column = ['radius_mean'], by = 'diagnosis')
fig = plot.gcf()
fig.set_size_inches(5, 5)

# %%
data.boxplot(column = ['texture_mean'], by = 'diagnosis')
fig = plot.gcf()
fig.set_size_inches(5, 5)

# %%
data.boxplot(column = ['perimeter_mean'], by = 'diagnosis')
fig = plot.gcf()
fig.set_size_inches(5, 5)

# %%
data.boxplot(column = ['area_mean'], by = 'diagnosis')
fig = plot.gcf()
fig.set_size_inches(5, 5)

# %%
data.boxplot(column = ['smoothness_mean'], by = 'diagnosis')
fig = plot.gcf()
fig.set_size_inches(5, 5)

# %%
data.boxplot(column = ['compactness_mean'], by = 'diagnosis')
fig = plot.gcf()
fig.set_size_inches(5, 5)

# %%
data.boxplot(column = ['concavity_mean'], by = 'diagnosis')
fig = plot.gcf()
fig.set_size_inches(5, 5)

# %%
data.boxplot(column = ['concave points_mean'], by = 'diagnosis')
fig = plot.gcf()
fig.set_size_inches(5, 5)

# %%
data.boxplot(column = ['fractal_dimension_worst'], by = 'diagnosis')
fig = plot.gcf()
fig.set_size_inches(5, 5)
